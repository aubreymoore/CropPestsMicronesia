# %% [markdown]
# # python-dwca-reader
# https://github.com/BelgianBiodiversityPlatform/python-dwca-reader

# %%
from dwca.read import DwCAReader
from dwca.darwincore.utils import qualname as qn

# %%
# Let's open our archive...
# Using the with statement ensure that resources will be properly freed/cleaned after use.
with DwCAReader('dwca.zip') as dwca:
    # We can now interact with the 'dwca' object

    # We can read scientific metadata (EML) through a xml.etree.ElementTree.Element object in the 'metadata'
    # attribute.
    dwca.metadata

    # The 'descriptor' attribute gives access to the Archive Descriptor (meta.xml) and allow
    # inspecting the archive:
    # For example, discover what the type the Core file is: (Occurrence, Taxon, ...)
    print("Core type is: %s" % dwca.descriptor.core.type)
    # => Core type is: http://rs.tdwg.org/dwc/terms/Occurrence

    # Check if a Darwin Core term in present in the core file
    if 'http://rs.tdwg.org/dwc/terms/locality' in dwca.descriptor.core.terms:
        print("This archive contains the 'locality' term in its core file.")
    else:
        print("Locality term is not present.")

    # Using full qualnames for DarwincCore terms (such as 'http://rs.tdwg.org/dwc/terms/country') is verbose...
    # The qualname() helper function make life easy for common terms.
    # (here, it has been imported as 'qn'):
    qn('locality')
    # => u'http://rs.tdwg.org/dwc/terms/locality'

    # Combined with previous examples, this can be used to things more clear:
    # For example:
    if qn('locality') in dwca.descriptor.core.terms:
        pass

    # Or:
    if dwca.descriptor.core.type == qn('Occurrence'):
        pass

    # Finally, let's iterate over the archive core rows and get the data:
    for row in dwca:
        # row is an instance of CoreRow
        # iteration respects their order of appearance in the core file

        # Print can be used for debugging purposes...
        print(row)

        # => --
        # => Rowtype: http://rs.tdwg.org/dwc/terms/Occurrence
        # => Source: Core file
        # => Row ID:
        # => Data: {u'http://rs.tdwg.org/dwc/terms/basisOfRecord': u'Observation', u'http://rs.tdwg.org/dwc/terms/family': # => u'Tetraodontidae', u'http://rs.tdwg.org/dwc/terms/locality': u'Borneo', u'http://rs.tdwg.#
        # => org/dwc/terms/scientificName': u'tetraodon fluviatilis'}
        # => --

        # You can get the value of a specific Darwin Core term through
        # the "data" dict:
        ## print("Value of 'locality' for this row: %s" % row.data[qn('locality')])
        # => Value of 'locality' for this row: Mumbai

    # Alternatively, we can get a list of core rows instead of iterating:
    # BEWARE: all rows will be loaded in memory!
    rows = dwca.rows

    # Or retrieve a specific row by its id:
    occurrence_number_three = dwca.get_row_by_id(3)

    # Caution: ids are generally a fragile way to identify a core row in an archive, since the standard dosn't guarantee unicity (nor even that there will be an id).
    # the index (position) of the row (starting at 0) is generally preferable.

    occurrence_on_second_line = dwca.get_row_by_index(1)

    # We can retreive the (absolute) of embedded files
    # NOTE: this path point to a temporary directory that will be removed at the end of the DwCAReader object life cycle.
    path = dwca.absolute_temporary_path('occurrence.txt')
# Out:
# Core type is: http://rs.tdwg.org/dwc/terms/Taxon
# Locality term is not present.
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/Taxon
# Source: Core file
# Row id: 876f6d22b15d4396be2b760bf415c955
# Reference extension rows: Yes
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/taxonRank': 'species', 'http://purl.org/dc/terms/bibliographicCitation': 'Moore2016', 'http://rs.tdwg.org/dwc/terms/scientificName': 'Agave sisalana', 'http://rs.tdwg.org/dwc/terms/kingdom': 'Plantae'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/Taxon
# Source: Core file
# Row id: 17c201c8da1847929a10109237aab0f4
# Reference extension rows: Yes
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/taxonRank': 'species', 'http://purl.org/dc/terms/bibliographicCitation': 'Moore2016', 'http://rs.tdwg.org/dwc/terms/scientificName': '
# Reference extension rows: Yes
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/taxonRank': 'species', 'http://purl.org/dc/terms/bibliographicCitation': 'Moore2016', 'http://rs.tdwg.org/dwc/terms/scientificName': 'Precis villida', 'http://rs.tdwg.org/dwc/terms/kingdom': 'Animalia'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/Taxon
# Source: Core file
# Row id: a635c7e7a86b4d70886068874f2639ac
# Reference extension rows: Yes
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/taxonRank': 'species', 'http://purl.org/dc/terms/bibliographicCitation': 'Moore2016', 'http://rs.tdwg.org/dwc/terms/scientificName': 'Hypolimnas bolina', 'http://rs.tdwg.org/dwc/terms/kingdom': 'Animalia'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/Taxon
# Source: Core file
# Row id: bcfdd0adbe7344c09cd273cbee9f2362
# Reference extension rows: Yes
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/taxonRank': 'species', 'http://purl.org/dc/terms/bibliographicCitation': 'Moore2016', 'http://rs.tdwg.org/dwc/terms/scientificName': 'Hippotion swinhoei', 'http://rs.tdwg.org/dwc/terms/kingdom': 'Animalia'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/Taxon
# Source: Core file
# Row id: 9ff4ceefd18c4952a8c1e4748485d90e
# Reference extension rows: Yes
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/taxonRank': 'genus', 'http://purl.org/dc/terms/bibliographicCitation': 'Moore2016', 'http://rs.tdwg.org/dwc/terms/scientificName': 'Gryllotalpa', 'http://rs.tdwg.org/dwc/terms/kingdom': 'Animalia'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/Taxon
# Source: Core file
# Row id: 505000344af24ce4b40bfce0b336eb35
# Reference extension rows: Yes
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/taxonRank': 'species', 'http://purl.org/dc/terms/bibliographicCitation': 'Moore2016', 'http://rs.tdwg.org/dwc/terms/scientificName': 'Colocasia esculenta', 'http://rs.tdwg.org/dwc/terms/kingdom': 'Plantae'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/Taxon
# Source: Core file
# Row id: fbbcc90fff7a428cb72b08117a10e2a1
# Reference extension rows: Yes
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/taxonRank': 'species', 'http://purl.org/dc/terms/bibliographicCitation': 'Moore2016', 'http://rs.tdwg.org/dwc/terms/scientificName': 'Atactus deplanatus', 'http://rs.tdwg.org/dwc/terms/kingdom': 'Animalia'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/Taxon
# Source: Core file
# Row id: e0e95cca067841feb6c34cbc827bb176
# Reference extension rows: Yes
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/taxonRank': 'species', 'http://purl.org/dc/terms/bibliographicCitation': 'Moore2016', 'http://rs.tdwg.org/dwc/terms/scientificName': 'Tarophagus proserpina', 'http://rs.tdwg.org/dwc/terms/kingdom': 'Animalia'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/Taxon
# Source: Core file
# Row id: 3d6cced3408d408aa0b56b6b5e63f617
# Reference extension rows: Yes
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/taxonRank': 'species', 'http://purl.org/dc/terms/bibliographicCitation': 'Moore2016', 'http://rs.tdwg.org/dwc/terms/scientificName': 'Hippotion celerio', 'http://rs.tdwg.org/dwc/terms/kingdom': 'Animalia'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/Taxon
# Source: Core file
# Row id: 14432a8b99454177b8561ba640aae578
# Reference extension rows: Yes
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/taxonRank': 'species', 'http://purl.org/dc/terms/bibliographicCitation': 'Moore2016', 'http://rs.tdwg.org/dwc/terms/scientificName': 'Theretra pinastrina', 'http://rs.tdwg.org/dwc/terms/kingdom': 'Animalia'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/Taxon
# Source: Core file
# Row id: c634dbef9d8a4e499f589cbe58e74978
# Reference extension rows: Yes
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/taxonRank': 'genus', 'http://purl.org/dc/terms/bibliographicCitation': 'Moore2016', 'http://rs.tdwg.org/dwc/terms/scientificName': 'Cyrtosperma', 'http://rs.tdwg.org/dwc/terms/kingdom': 'Plantae'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/Taxon
# Source: Core file
# Row id: d5805140aa11481a9079a6c382663f94
# Reference extension rows: Yes
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/taxonRank': 'species', 'http://purl.org/dc/terms/bibliographicCitation': 'Moore2016', 'http://rs.tdwg.org/dwc/terms/scientificName': 'Pseudococcus macrocirculus', 'http://rs.tdwg.org/dwc/terms/kingdom': 'Animalia'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/Taxon
# Source: Core file
# Row id: 4965829e009247e49537f7f10957753f
# Reference extension rows: Yes
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/taxonRank': 'species', 'http://purl.org/dc/terms/bibliographicCitation': 'Moore2016', 'http://rs.tdwg.org/dwc/terms/scientificName': 'Lycopersicon esculentum', 'http://rs.tdwg.org/dwc/terms/kingdom': 'Plantae'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/Taxon
# Source: Core file
# Row id: 85086eeeac3a43a3b9a97a7ff2d50bcf
# Reference extension rows: Yes
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/taxonRank': 'species', 'http://purl.org/dc/terms/bibliographicCitation': 'Moore2016', 'http://rs.tdwg.org/dwc/terms/scientificName': 'Cyrtopeltis tenuis', 'http://rs.tdwg.org/dwc/terms/kingdom': 'Animalia'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/Taxon
# Source: Core file
# Row id: 545790842048408bb4201caaf12e54ce
# Reference extension rows: Yes
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/taxonRank': 'species', 'http://purl.org/dc/terms/bibliographicCitation': 'Moore2016', 'http://rs.tdwg.org/dwc/terms/scientificName': 'Nesophrosyne argentatus', 'http://rs.tdwg.org/dwc/terms/kingdom': 'Animalia'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/Taxon
# Source: Core file
# Row id: b75b728a89b84e26a4267366faac2033
# Reference extension rows: Yes
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/taxonRank': 'genus', 'http://purl.org/dc/terms/bibliographicCitation': 'Moore2016', 'http://rs.tdwg.org/dwc/terms/scientificName': 'Terminalia', 'http://rs.tdwg.org/dwc/terms/kingdom': 'Plantae'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/Taxon
# Source: Core file
# Row id: 116b296a0134473dbb43ed07f809330a
# Reference extension rows: Yes
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/taxonRank': 'species', 'http://purl.org/dc/terms/bibliographicCitation': 'Moore2016', 'http://rs.tdwg.org/dwc/terms/scientificName': 'Trigonops vulgaris', 'http://rs.tdwg.org/dwc/terms/kingdom': 'Animalia'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/Taxon
# Source: Core file
# Row id: d4730a22d40a46f299c8ff1df4505f3c
# Reference extension rows: Yes
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/taxonRank': 'species', 'http://purl.org/dc/terms/bibliographicCitation': 'Moore2016', 'http://rs.tdwg.org/dwc/terms/scientificName': 'Dialeurodes kirkaldyi', 'http://rs.tdwg.org/dwc/terms/kingdom': 'Animalia'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/Taxon
# Source: Core file
# Row id: 14c9c8febc92492eb371bfc56491e33b
# Reference extension rows: Yes
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/taxonRank': 'species', 'http://purl.org/dc/terms/bibliographicCitation': 'Moore2016', 'http://rs.tdwg.org/dwc/terms/scientificName': 'Badamia exclamationis', 'http://rs.tdwg.org/dwc/terms/kingdom': 'Animalia'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/Taxon
# Source: Core file
# Row id: d306d95564c148a6ac36c0b50eb41b75
# Reference extension rows: Yes
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/taxonRank': 'species', 'http://purl.org/dc/terms/bibliographicCitation': 'Moore2016', 'http://rs.tdwg.org/dwc/terms/scientificName': 'Anua coronata', 'http://rs.tdwg.org/dwc/terms/kingdom': 'Animalia'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/Taxon
# Source: Core file
# Row id: 7e42fff30b2d4ab6bf2109478641ad14
# Reference extension rows: Yes
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/taxonRank': 'species', 'http://purl.org/dc/terms/bibliographicCitation': 'Moore2016', 'http://rs.tdwg.org/dwc/terms/scientificName': 'Psophocarpus tetragonalubus', 'http://rs.tdwg.org/dwc/terms/kingdom': 'Plantae'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/Taxon
# Source: Core file
# Row id: 338d8f3eb2404e4390c745a62c6cfbab
# Reference extension rows: Yes
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/taxonRank': 'species', 'http://purl.org/dc/terms/bibliographicCitation': 'Moore2016', 'http://rs.tdwg.org/dwc/terms/scientificName': 'Tetranychus neocaledonicus', 'http://rs.tdwg.org/dwc/terms/kingdom': 'Animalia'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/Taxon
# Source: Core file
# Row id: 019b64c3980c443c8bb814d94f6b1857
# Reference extension rows: Yes
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/taxonRank': 'genus', 'http://purl.org/dc/terms/bibliographicCitation': 'Moore2016', 'http://rs.tdwg.org/dwc/terms/scientificName': 'Dioscorea', 'http://rs.tdwg.org/dwc/terms/kingdom': 'Plantae'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/Taxon
# Source: Core file
# Row id: 22cd5092082b4ba99c8fc7baf1edc54c
# Reference extension rows: Yes
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/taxonRank': 'species', 'http://purl.org/dc/terms/bibliographicCitation': 'Moore2016', 'http://rs.tdwg.org/dwc/terms/scientificName': 'Theretra nessus', 'http://rs.tdwg.org/dwc/terms/kingdom': 'Animalia'}
# --
# ---------------------------------------------------------------------------
# RowNotFound                               Traceback (most recent call last)
# <ipython-input-4-b7cc0251df53> in <module>()
#      61
#      62     # Or retrieve a specific row by its id:
# ---> 63     occurrence_number_three = dwca.get_row_by_id(3)
#      64
#      65     # Caution: ids are generally a fragile way to identify a core row in an archive, since the standard dosn't guarantee unicity (nor even that there will be an id).
#
# /home/aubreymoore/anaconda3/lib/python3.5/site-packages/dwca/read.py in get_row_by_id(self, row_id)
#     156                 return row
#     157         else:
# --> 158             raise RowNotFound
#     159
#     160     def get_row_by_index(self, index):
#
# RowNotFound:

# %% [markdown]
# ### Access to Darwin Core Archives with extensions (star schema)

# %%
from dwca.read import DwCAReader

with DwCAReader('dwca.zip') as dwca:
    # Let's ask the archive what kind of extensions are in use:
    for e in dwca.descriptor.extensions:
        print(e.type)
    # => http://rs.gbif.org/terms/1.0/VernacularName

    first_core_row = dwca.rows[0]

    # Extension rows are accessible from a core row as a list of ExtensionRow instances:
    for extension_line in first_core_row.extensions:
        # Display all rows from extension files reffering to the first Core row
        print(extension_line)
# Out:
# http://rs.gbif.org/terms/1.0/Distribution
# http://rs.gbif.org/terms/1.0/VernacularName
# http://rs.tdwg.org/dwc/terms/ResourceRelationship
# --
# Rowtype: http://rs.gbif.org/terms/1.0/VernacularName
# Source: Extension file
# Core row id: 876f6d22b15d4396be2b760bf415c955
# Reference extension rows: No
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/vernacularName': 'Agave'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/ResourceRelationship
# Source: Extension file
# Core row id: 876f6d22b15d4396be2b760bf415c955
# Reference extension rows: No
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/relationshipOfResource': 'host plant of', 'http://rs.tdwg.org/dwc/terms/relatedResourceID': '17c201c8da1847929a10109237aab0f4'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/ResourceRelationship
# Source: Extension file
# Core row id: 876f6d22b15d4396be2b760bf415c955
# Reference extension rows: No
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/relationshipOfResource': 'host plant of', 'http://rs.tdwg.org/dwc/terms/relatedResourceID': '311cf11008e54e33a9259ed045b47b23'}
# --

# %% [markdown]
# ### Another example with multiple extensions (no new API here)

# %%
with DwCAReader('dwca.zip') as dwca:
    rows = dwca.rows
    ostrich = rows[10]

    print("You'll find below all extensions rows reffering to Ostrich")
    print("There should be 3 vernacular names and 2 taxon description")
    for ext in ostrich.extensions:
        print(ext)

    print("We can then simply filter by type...")
    for ext in ostrich.extensions:
        if ext.rowtype == 'http://rs.gbif.org/terms/1.0/VernacularName':
            print(ext)
# Out:
# You'll find below all extensions rows reffering to Ostrich
# There should be 3 vernacular names and 2 taxon description
# --
# Rowtype: http://rs.gbif.org/terms/1.0/Distribution
# Source: Extension file
# Core row id: 45781c22862548c1821c8faa424feb75
# Reference extension rows: No
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/occurrenceRemarks': '', 'http://rs.tdwg.org/dwc/terms/locality': 'Republic of Palau'}
# --
#
# --
# Rowtype: http://rs.gbif.org/terms/1.0/Distribution
# Source: Extension file
# Core row id: 45781c22862548c1821c8faa424feb75
# Reference extension rows: No
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/occurrenceRemarks': '', 'http://rs.tdwg.org/dwc/terms/locality': 'Saipan'}
# --
#
# --
# Rowtype: http://rs.gbif.org/terms/1.0/Distribution
# Source: Extension file
# Core row id: 45781c22862548c1821c8faa424feb75
# Reference extension rows: No
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/occurrenceRemarks': '', 'http://rs.tdwg.org/dwc/terms/locality': 'Tinian'}
# --
#
# --
# Rowtype: http://rs.gbif.org/terms/1.0/Distribution
# Source: Extension file
# Core row id: 45781c22862548c1821c8faa424feb75
# Reference extension rows: No
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/occurrenceRemarks': '', 'http://rs.tdwg.org/dwc/terms/locality': 'Rota'}
# --
#
# --
# Rowtype: http://rs.gbif.org/terms/1.0/Distribution
# Source: Extension file
# Core row id: 45781c22862548c1821c8faa424feb75
# Reference extension rows: No
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/occurrenceRemarks': '', 'http://rs.tdwg.org/dwc/terms/locality': 'Guam'}
# --
#
# --
# Rowtype: http://rs.gbif.org/terms/1.0/VernacularName
# Source: Extension file
# Core row id: 45781c22862548c1821c8faa424feb75
# Reference extension rows: No
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/vernacularName': 'long brown scale'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/ResourceRelationship
# Source: Extension file
# Core row id: 45781c22862548c1821c8faa424feb75
# Reference extension rows: No
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/relationshipOfResource': 'herbivore of', 'http://rs.tdwg.org/dwc/terms/relatedResourceID': '66bd6c0b2d4c4a5e98eed112a44bc291'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/ResourceRelationship
# Source: Extension file
# Core row id: 45781c22862548c1821c8faa424feb75
# Reference extension rows: No
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/relationshipOfResource': 'herbivore of', 'http://rs.tdwg.org/dwc/terms/relatedResourceID': '53ced460a83e4d85870479a4da3c042d'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/ResourceRelationship
# Source: Extension file
# Core row id: 45781c22862548c1821c8faa424feb75
# Reference extension rows: No
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/relationshipOfResource': 'herbivore of', 'http://rs.tdwg.org/dwc/terms/relatedResourceID': '12fcc7c4155b4aa68bccfbc8b0b0bd43'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/ResourceRelationship
# Source: Extension file
# Core row id: 45781c22862548c1821c8faa424feb75
# Reference extension rows: No
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/relationshipOfResource': 'herbivore of', 'http://rs.tdwg.org/dwc/terms/relatedResourceID': '2bd6072689f9496a80127325061389cd'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/ResourceRelationship
# Source: Extension file
# Core row id: 45781c22862548c1821c8faa424feb75
# Reference extension rows: No
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/relationshipOfResource': 'herbivore of', 'http://rs.tdwg.org/dwc/terms/relatedResourceID': '71acc6c6dbca4f7e831d60d36d4d6931'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/ResourceRelationship
# Source: Extension file
# Core row id: 45781c22862548c1821c8faa424feb75
# Reference extension rows: No
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/relationshipOfResource': 'herbivore of', 'http://rs.tdwg.org/dwc/terms/relatedResourceID': 'ed16d7e38ecc4f3796984348240f4df5'}
# --
#
# --
# Rowtype: http://rs.tdwg.org/dwc/terms/ResourceRelationship
# Source: Extension file
# Core row id: 45781c22862548c1821c8faa424feb75
# Reference extension rows: No
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/relationshipOfResource': 'herbivore of', 'http://rs.tdwg.org/dwc/terms/relatedResourceID': 'bb3a79494eb24f8ea55bb3e335f2f319'}
# --
#
# We can then simply filter by type...
# --
# Rowtype: http://rs.gbif.org/terms/1.0/VernacularName
# Source: Extension file
# Core row id: 45781c22862548c1821c8faa424feb75
# Reference extension rows: No
# Reference source metadata: No
# Data: {'http://rs.tdwg.org/dwc/terms/vernacularName': 'long brown scale'}
# --
